# %% [markdown]
# # References

# %%
# !ls -laFh ../data/from-web
# Out:
# total 18M
# drwxr-xr-x 7 root root  224 Apr  5 14:58 ./
# drwxr-xr-x 6 root root  192 Apr  5 15:03 ../
# -rw-r--r-- 1 root root 2.2M Apr  5 12:27 161209_Schenker_Sensordaten.csv
# -rw-r--r-- 1 root root 1.6M Apr  5 14:53 DBNetz-Betriebsstellenverzeichnis-Stand2017-01.csv
# -rw-r--r-- 1 root root 667K Apr  5 14:58 DBSuS-Uebersicht_Bahnhoefe-Stand2016-07.csv
# -rw-r--r-- 1 root root 460K Apr  5 14:45 D_Bahnhof_2017_09.csv
# -rw-r--r-- 1 root root  13M Apr  5 14:34 geo-strecke.zip

# %%
import pandas as pd

# %%
df_ssf = pd.read_csv('../data/from-web/161209_Schenker_Sensordaten.csv')

# %%
df_ssf.head()
# Out:
#   index SXXJ number Container          Date    Time_UTC       Latitude  \
# 0     #        [No]      [No]  [yyyy-MM-dd]  [hh:mm:ss]  [deg decimal]
# 1     0           A      NONE    2016-08-08    14:39:36            NaN
# 2     1           A      NONE    2016-08-08    14:39:45            NaN
# 3     2           A      NONE    2016-08-08    14:40:34      25.794100
# 4     3           A      NONE    2016-08-08    15:57:46            NaN
#
#        Longitude Accuracy        Active       Reverse     ...      \
# 0  [deg decimal]      [m]  [1=yes|0=no]  [1=yes|0=no]     ...
# 1            NaN      NaN             0             0     ...
# 2            NaN      NaN             0             0     ...
# 3     -80.369301   cellid             0             0     ...
# 4            NaN      NaN             1             0     ...
#
#                 Door                      Mount                  Motion  \
# 0  [1=open|0=closed]  [1=not mounted|0=mounted]  [1=motion|0=no motion]
# ...

# %%
df_sta = pd.read_csv('../data/from-web/DBNetz-Betriebsstellenverzeichnis-Stand2017-01.csv', sep=';')

# %%
df_sta.head()
# Out:
#      Abk                Name        Kurzname  Typ Betr-Zust  \
# 0     AA      Hamburg-Altona  Hamburg-Altona   Bf       NaN
# 1  AA  G  Hamburg-Altona Gbf  Hmb-Altona Gbf  Bft       NaN
# 2   AABG         Agathenburg     Agathenburg   Hp       NaN
# 3   AACW          Achterwehr      Achterwehr   Hp       NaN
# 4   AADF            Adendorf        Adendorf   Bf       NaN
#
#   Primary location code  UIC   RB  gültig von  gültig bis  Netz-Key Fpl-rel  \
# 0               DE14421   80  2.0    20081214         NaN   10934.0       J
# 1               DE14423   80  2.0    20081214         NaN  908650.0       J
# 2               DE10046   80  2.0    20081214         NaN   11924.0       J
# 3               DE10031   80  2.0    20141214         NaN  106933.0       J
# 4               DE10040   80  2.0    20081214         NaN   11601.0       J
#
#   Fpl-Gr
# 0      N
# 1      N
# 2      N
# 3      N
# 4      N

# %%
df_routes = pd.read_csv('../data/from-web/DBSuS-Uebersicht_Bahnhoefe-Stand2016-07.csv', sep=';')

# %%
df_routes.head()
# Out:
#             Bundesland      BM  Bf. Nr.            Station Bf DS 100 Abk.  \
# 0  Nordrhein-Westfalen  Aachen        1         Aachen Hbf             KA
# 1  Nordrhein-Westfalen  Aachen        2  Aachen-Rothe Erde           KARE
# 2  Nordrhein-Westfalen  Aachen        3        Aachen West            KAW
# 3  Nordrhein-Westfalen  Aachen      184            Arsbeck           KARS
# 4  Nordrhein-Westfalen  Aachen      235   Hückelhoven-Baal            KBA
#
#    Kat. Vst           Straße    PLZ               Ort  \
# 0         2  Bahnhofplatz 2a  52064            Aachen
# 1         4     Beverstr. 48  52066            Aachen
# 2         5  Republikplatz 1  52072            Aachen
# 3         7       Heidestr.1  41844           Wegberg
# 4         4       Bahnstr.11  41836  Hückelhoven-Baal
#
#                            Aufgabenträger
# 0  Zweckverband Nahverkehr Rheinland GmbH
# 1  Zweckverband Nahverkehr Rheinland GmbH
# 2  Zweckverband Nahverkehr Rheinland GmbH
# ...
